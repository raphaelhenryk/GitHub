# %%
import matplotlib.pyplot as plt

year = [1958 , 1959 , 1993 , 1996]
salary = [1500, 0 , 6690 , 0]

plt1 = plt.plot(year, salary)
plt2 = plt.scatter(year, salary)


#plt.show(plt1)
plt.show(plt2)
