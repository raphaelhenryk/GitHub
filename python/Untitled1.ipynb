# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
amzn = pdr.get_data_yahoo('AMZN', '20121101')
goog = pdr.get_data_yahoo('GOOG', '2012-11-01')
ambv = pdr.get_data_yahoo('ABEV', '20121101')

# %%
ambv.tail()
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2019-05-17  4.17  4.01  4.11   4.05  38060800.0       4.05
# 2019-05-20  4.08  4.00  4.02   4.04  37947200.0       4.04
# 2019-05-21  4.25  4.05  4.09   4.21  19373000.0       4.21
# 2019-05-22  4.30  4.22  4.25   4.25  36243500.0       4.25
# 2019-05-23  4.32  4.21  4.22   4.26  21291285.0       4.26

# %%
ambv
# Out:
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2010-01-04  3.6000  3.4884  3.4884  3.6000     40000.0   1.505034
# 2010-01-05  3.5800  3.5408  3.5800  3.5752    187500.0   1.494666
# 2010-01-06  3.6200  3.5652  3.5684  3.5944    117500.0   1.502693
# 2010-01-07  3.6008  3.5396  3.5920  3.5804    135000.0   1.496839
# 2010-01-08  3.6392  3.5776  3.5776  3.6372    222500.0   1.520586
# 2010-01-11  3.6012  3.5888  3.6008  3.5888     37500.0   1.500351
# 2010-01-12  3.5652  3.4992  3.4992  3.5600    182500.0   1.488311
# 2010-01-13  3.5940  3.5532  3.5940  3.5668     57500.0   1.491154
# 2010-01-14  3.6632  3.5472  3.5528  3.6200    102500.0   1.513395
# 2010-01-15  3.6252  3.5564  3.6252  3.5572    107500.0   1.487140
# 2010-01-19  3.6400  3.5736  3.5864  3.5960    332500.0   1.503361
# 2010-01-20  3.5752  3.4524  3.5748  3.4868   1230000.0   1.457708
# 2010-01-21  3.5440  3.3580  3.5200  3.4776    807500.0   1.453863
# ...

# %%
print(amzn.info(), goog.info(), ambv.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1649 entries, 2012-11-01 to 2019-05-22
# Data columns (total 6 columns):
# High         1649 non-null float64
# Low          1649 non-null float64
# Open         1649 non-null float64
# Close        1649 non-null float64
# Volume       1649 non-null int64
# Adj Close    1649 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 90.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1649 entries, 2012-11-01 to 2019-05-22
# Data columns (total 6 columns):
# High         1649 non-null float64
# Low          1649 non-null float64
# Open         1649 non-null float64
# Close        1649 non-null float64
# Volume       1649 non-null float64
# Adj Close    1649 non-null float64
# dtypes: float64(6)
# memory usage: 90.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1649 entries, 2012-11-01 to 2019-05-22
# Data columns (total 6 columns):
# High         1649 non-null float64
# ...

# %%
a = list(range(100000))
# %timeit [val + 5 for val in a]
# Out:
# 6.31 ms ± 91.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
a = np.array(a)
# %timeit a + 5
# Out:
# 70.7 µs ± 911 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import numpy as np
array1 = np.array([2,6,4])
array2 = np.array([True, False, True])

array3 = array1 / array2

print(array3)
# Out:
# [ 2. inf  4.]
# C:\Users\RAPHAELHENRYKDASILVA\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
